# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Mariana Valenzuela Lafarga y Brisa Michelle Valadez Tovar
#
# **Fecha:** 14 de Marzo del 2023.
#
# **Expediente** : XXX | 734547
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/MarianaVal06/ProyectoConjunto_MValenzuela_MValdez
#
# # Tarea 5: Clase 10

# %% [markdown]
# # <font color ='red'> **Tarea 5**
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
# ![image.png](attachment:image.png)

# %% [markdown]
# Código de solución estudiante 1

# %%
#Codigo de solucion estudiante 1 
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
f = lambda x: 30 *(x**2 - 2*x**3 + x**4)
a=f(optimize.fmin(lambda x:-f(x), 0, disp=False))
t =lambda x: a*np.sin(np.pi*x)
x = np.arange(0, 1, 0.01)
print('El máximo de f es:',a)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# 2. Funcion de densidad $g(x)$
# $$g(x)=\frac{t(x)}{C}$$
# $$C=\int_{0}^{1}t(x)dx$$
# $$C= \int a\sin(\pi x) dx= \frac{-a}{\pi}\cos(\pi x)$$
# $$=\int_{0}^{1}a\sin(\pi x)dx= [\frac{-a}{\pi}\cos(\pi)] - [\frac{-a}{\pi} \cos(0)]$$
# $$ [\frac{-a}{\pi}\cos(-1)] - [\frac{-a}{\pi} \cos(1)]$$
# $$C=\frac{2a}{\pi}$$
# $$g(x)=\frac{a\sin(\pi x)}{\frac{2a}{\pi}}$$
# $$g(x)=\frac{\sin(\pi x)}{\frac{2}{\pi}}$$

# %% [markdown]
# 3. Distribucion de probabilidad acumulada $G(x)$
# $$G(x)=\int_{0}^{x} g(x)dx$$
# $$=\int \frac{sin(\pi x)}{2\pi}dx= -(\frac{1}{2})\cos(\pi x)+C$$
# $$\int_{0}^{x} \frac{\sin(\pi x)}{2\pi}dx=[-(\frac{1}{2}\pi)\cos(\pi x)]-[-(\frac{1}{2}\pi)\cos(\pi(0))]$$
# $$=[-(\frac{1}{2}\pi)\cos(\pi x)]-[-(\frac{1}{2}\pi)]$$
# $$G(x)=[-(\frac{1}{2}\pi)\cos(\pi x)]+ \frac{1}{2\pi}$$

# %% [markdown]
# Despejar $x$
# $$G(x)=U$$
# $$[-(\frac{1}{2}\pi)\cos(\pi x)]+ \frac{1}{2\pi}=U$$
# $$[-(\frac{1}{2}\pi)\cos(\pi x)]=U-\frac{1}{2\pi}$$
# $$\cos(\pi x)= -2\pi(U-\frac{1}{2\pi}) $$
# $$\pi x= \arccos[-2\pi(U-\frac{1}{2\pi})]$$
# $$x= \frac{1}{\pi} \arccos[-2\pi (U-\frac{1}{2\pi})]$$

# %%
def distribucion(N):
    return ((1/np.pi)*np.arccos(-2*np.pi*(np.random.random(N)-(1/(2*np.pi)))))
N=10**6
g= lambda g:((np.sin(np.pi*x)/(2/np.pi)))
x= np.arange(0,1,.01)
x1= distribucion(N)
plt.plot(x,g(x),label='g(x)')
plt.hist(x1,100,density=True)
plt.xlabel('valores aleatorios')
plt.ylabel('probabilidad')
plt.title('histograma función creada')
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_72236\104726404.py:2: RuntimeWarning: invalid value encountered in arccos
#   return ((1/np.pi)*np.arccos(-2*np.pi*(np.random.random(N)-(1/(2*np.pi)))))

# %% [markdown]
# Código de solución estudiante 2

# %%
# Código de solución estudiante 2
#1. 

# Función objetivo 
f = lambda x: 30 *(x**2 - 2*x**3 + x**4)

# Máximo de la función f
max_f=f(optimize.fmin(lambda x:-f(x), 0, disp=False))

# Función t -> Función constante
t =lambda x: max_f*np.sin(np.pi*x)

# Rango donde se graficará las funciones
x = np.arange(0, 1, 0.01)

# Gráficas de las funciones
print('El máximo de f es:',max_f)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# 2.
# Definimos la función: $$g(x)=\frac{t(x)}{c}$$
#
# $$c=\int_{0}^{1} a \sin (\pi x) dx$$
#
# Siendo  $u = \pi x$, entonces $du = \pi dx$
#
# $$\frac{1}{\pi} \int_{0}^{1} a \sin (u) du = \frac{a}{\pi} [-\cos(u)]_{0}^{\pi} = \frac{2a}{\pi} $$
#
# Por lo tanto la función de densidad es:
#
# $$g(x) = \frac{t(x)}{\int_{0}^{1}t(x) dx} = \frac{a\sin(\pi x)}{\frac{2a}{\pi}} = \frac{\pi}{2}\sin(\pi x)$$

# %% [markdown]
# 3.
#
# $$ G(x) = \int_{0}^{x} \frac{\pi}{2}\sin(\pi u) du = [-\frac{\cos (\pi u)}{2\pi} ]_{0}^{\pi} = \frac{1}{2}-\frac{\cos (\pi x)}{2\pi} $$
#
# $$ \frac{1}{2}-\frac{\cos (\pi x)}{2\pi} = U $$
#
# Despejamos X
#
# $$\cos(\pi x )  = 1-2\pi U $$
# $$x = \frac{1}{\pi}\arccos(1-2\pi U)$$

# %%
def distribucion(N):
    return ((1/np.pi)*np.arccos(-2*np.pi*(np.random.random(N)-(1/(2*np.pi)))))

# %%
N=10**6
g= lambda g:((np.sin(np.pi*x)/(2/np.pi)))
x= np.arange(0,1,.01)
x1= distribucion(N)
plt.plot(x,g(x),label="g(x)")
plt.hist(x1,100,density=True)
plt.xlabel("Valores aleatorios")
plt.ylabel("Probabilidades")
plt.title("Histograma")
plt.show()
# Out:
# C:\Users\miche\AppData\Local\Temp\ipykernel_21960\1218074720.py:2: RuntimeWarning: invalid value encountered in arccos
#   return ((1/np.pi)*np.arccos(-2*np.pi*(np.random.random(N)-(1/(2*np.pi)))))

# %% [markdown]
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![image.png](attachment:image.png)

# %%
#Código de solución estudiante 1
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
N = 500 # número de puntos a simular
# Como estoy tomando t(x) constante solo es necesario generar valores aleatorios U~(0,1)
R2 = np.random.rand(N)
R1 = np.random.rand(N)

x2 = np.arange(0,1,0.01)

plt.plot(x2,f(x2),'k')
plt.plot(x2,t(x2),'b')

Acep_rechazo(R2, R1, f, t)

# %%
#Código de solución estudiante 2

def Acep_rechazo(R2:"Variables distruidas U~U(0,1)",
                 R1:"Variables distribuidas como g(x)",
                 f:"función objetivo a generar",
                 t:"función que mayora a f"):
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],"ob") if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],"o") \
         for i in range(len(R1))]
                
    plt.show()
    

N = 500 

R2 = np.random.rand(N)
R1 = np.random.rand(N)

x2 = np.arange(0,1,0.01)

plt.plot(x2,f(x2),'k')
plt.plot(x2,t(x2),'b')

Acep_rechazo(R2, R1, f, t)

# %% [markdown]
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %%
#Código de solución estudiante 1
f1 = lambda x: 30 *(x**2 - 2*x**3 + x**4)
a1=f1(optimize.fmin(lambda x:-f1(x), 0, disp=False))
t1 = lambda x: a1 * np.ones(len(x))
x = np.arange(0, 1, 0.01)

# %%
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x1 = f1(R1)
    t_x1 = t1(R1)
    condition = R2*t_x1 <=f_x1
    [plt.plot(R1[i],R2[i]*t_x1[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x1[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
N = 500 
R2 = np.random.rand(N)
R1 = np.random.rand(N)
plt.plot(x,f1(x),label='f(x)')
plt.plot(x,t1(x),label='t(x)')
plt.legend()
Acep_rechazo(R2, R1, f1, t1)

# %%
#Código de solución estudiante 2

f1 = lambda x: 30 *(x**2 - 2*x**3 + x**4)
a1=f1(optimize.fmin(lambda x:-f1(x), 0, disp=False))
t1 = lambda x: a1 * np.ones(len(x))
x = np.arange(0, 1, 0.01)

def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x1 = f1(R1)
    t_x1 = t1(R1)
    condition = R2*t_x1 <=f_x1
    [plt.plot(R1[i],R2[i]*t_x1[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x1[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

    
    
N = 500 
R2 = np.random.rand(N)
R1 = np.random.rand(N)
plt.plot(x,f1(x),label='f(x)')
plt.plot(x,t1(x),label='t(x)')
plt.legend()
Acep_rechazo(R2, R1, f1, t1)

# %% [markdown]
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %%
#Código de solución estudiante 1
f2 = lambda x: 20*x *(1-x)**3
a2=f2(optimize.fmin(lambda x:-f2(x), 0, disp=False))
t2 =lambda x: a2 * np.ones(len(x))
x = np.arange(0, 1, 0.01)
print('El máximo de f es:',a2)
# Out:
# El máximo de f es: [2.109375]

# %%
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x2 = f2(R1)
    t_x2 = t2(R1)
    condition = R2*t_x2 <=f_x2
    [plt.plot(R1[i],R2[i]*t_x2[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x2[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
N = 500 
R2 = np.random.rand(N)
R1 = np.random.rand(N)
plt.plot(x,f2(x),label='f(x)')
plt.plot(x,t2(x),label='t(x)')
plt.legend()
Acep_rechazo(R2, R1, f2, t2)

# %%
#Código de solución estudiante 2

def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x2 = f2(R1)
    t_x2 = t2(R1)
    condition = R2*t_x2 <=f_x2
    [plt.plot(R1[i],R2[i]*t_x2[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x2[i],'o') \
         for i in range(len(R1))]
                
    plt.show()
    

# Función objetivo 
f2 = lambda x: 20*x *(1-x)**3
# Máximo de la función f
max_f2=f2(optimize.fmin(lambda x:-f2(x), 0, disp=False))
# Función t -> Función constante
t2 =lambda x:  max_f2* np.ones(len(x))
# Rango donde se graficará las funciones
x = np.arange(0, 1, 0.01)
print('El máximo de f es:',max_f2)


N = 500 
R2 = np.random.rand(N)
R1 = np.random.rand(N)
plt.plot(x,f2(x),label='f(x)')
plt.plot(x,t2(x),label='t(x)')
plt.legend()
Acep_rechazo(R2, R1, f2, t2)
# Out:
# El máximo de f es: [2.109375]
